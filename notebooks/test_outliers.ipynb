# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import make_blobs

from src.outlier_generator import OutlierGenerator
from src.read_dataset import load, AVAILABLE

# %%
X_normal, _ = make_blobs(n_samples=300, centers=2, cluster_std=0.8, random_state=42)
X_normal = pd.DataFrame(X_normal)

X_normal
# Out:
#             0          1
# 0    4.910676   1.640939
# 1    5.150753   0.643954
# 2   -2.519995   8.168117
# 3    5.077557   1.811416
# 4    4.871699   3.633490
# ..        ...        ...
# 295 -2.327230  10.060000
# 296  3.143245   1.691959
# 297  3.009379   1.166701
# 298  4.272390   1.293294
# 299  5.989592   2.678481
#
# [300 rows x 2 columns]

# %%
df, meta = load(name=AVAILABLE[0])

df
# Out:
# [HAR] loaded 10299 samples, 562 columns
#              f0        f1        f2  ...      f559      f560  label
# 0      0.288585 -0.020294 -0.132905  ...  0.179941 -0.058627      5
# 1      0.278419 -0.016411 -0.123520  ...  0.180289 -0.054317      5
# 2      0.279653 -0.019467 -0.113462  ...  0.180637 -0.049118      5
# 3      0.279174 -0.026201 -0.123283  ...  0.181935 -0.047663      5
# 4      0.276629 -0.016570 -0.115362  ...  0.185151 -0.043892      5
# ...         ...       ...       ...  ...       ...       ...    ...
# 10294  0.310155 -0.053391 -0.099109  ...  0.274627  0.184784      2
# 10295  0.363385 -0.039214 -0.105915  ...  0.273578  0.182412      2
# 10296  0.349966  0.030077 -0.115788  ...  0.274479  0.181184      2
# 10297  0.237594  0.018467 -0.096499  ...  0.264782  0.187563      2
# 10298  0.153627 -0.018437 -0.137018  ...  0.263936  0.188103      2
#
# [10299 rows x 562 columns]

# %%
plt.scatter(df.iloc[:, 0], df.iloc[:, 1])
plt.show()

# %%
model = OutlierGenerator(estimator=LogisticRegression())

outliers = model.generate_outliers(df)

# model.fit(df)

X = np.vstack([df, outliers])

plt.scatter(X[:, 0], X[:, 1])
plt.show()
